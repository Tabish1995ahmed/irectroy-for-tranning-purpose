# %% [markdown]
# # JPEG image loading and handling

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# print(img.shape)
# plt.imshow(img)  #red, green, blue

# %%
img = mpimg.imread('new.jpg')  #laod image
print(img.shape)
plt.imshow(img)
# Out:
# (891, 693, 3)

# %%
img[:,:,0] #slice only R Cha
# Out:
# array([[228, 228, 228, ..., 229, 229, 229],
#        [228, 228, 228, ..., 229, 229, 229],
#        [228, 228, 228, ..., 229, 229, 229],
#        ...,
#        [ 13,  12,  11, ...,  15,  16,  16],
#        [ 13,  12,  12, ...,  15,  15,  15],
#        [ 14,  13,  12, ...,  15,  15,  14]], dtype=uint8)

# %% [markdown]
# # Read PNG image format

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('girl.png',format='png')  #laod image
print(img.shape)
plt.imshow(img)
# Out:
# (550, 920, 4)

# %%
#image with photo viewer application 

from PIL import Image

img = Image.open('girl.png')
img.show()

# %% [markdown]
# # Working with OpenCV

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (38.2 MB)
#      ---------------------------------------- 38.2/38.2 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.68
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

image = cv2.imread('new.jpg') #GBR<-RGB
plt.imshow(img)
plt.show()

# %%
#import cv2

#image = cv2.imread('new.jpg')
#img = cv2.cvtColor(img, cv2.COLOR_RGB2GBR)   
##plt.imshow(img)
#plt.show()

# %% [markdown]
# # Handle data with tensorflow from any folder directroy for tranning purpose

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_datagen = ImageDataGenerator(re)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20428\1507047461.py in <module>
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       2
#       3 training_datagen = ImageDataGenerator(re)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.11.0
# Note: you may need to restart the kernel to use updated packages.
